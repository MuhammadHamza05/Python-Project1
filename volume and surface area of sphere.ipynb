# %%
# Volume And Surface Area of a Sphere

radius=int(input("Enter the radius of sphere :"))
volume=(4/3)*3.142*(radius**3)
surfacearea=4*3.142*(radius**2)
print("volume of sphere is :",volume)
print("surfacearea of sphere is :",surfacearea)
# Out:
# Enter the radius of sphere :10
# volume of sphere is : 4189.333333333333
# surfacearea of sphere is : 1256.8
